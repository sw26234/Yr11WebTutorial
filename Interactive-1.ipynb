# %% [markdown]
# 已连接到 Python 3.14.5

# %%
from bottle import route,run

@route('/hello')
def run():
    return "What's up my hello!"

run(host='localhost', port=8080)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3 @route('/hello')
#       4 def run():
#       5     return "What's up my hello!"
# ----> 7 run(host='localhost', port=8080)
#
# TypeError: run() got an unexpected keyword argument 'host'

# %%
from bottle import route,run

@route('/hello')
def run():
    return "What's up my hello!"

run(host='localhost', port=8080)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       3 @route('/hello')
#       4 def run():
#       5     return "What's up my hello!"
# ----> 7 run(host='localhost', port=8080)
#
# TypeError: run() got an unexpected keyword argument 'host'

# %%
from bottle import route, run

@route('/hello')
def hello():
    return "What's up my hello!"

run(host='localhost', port=8080)
# Out:
# Bottle v0.13.4 server starting up (using WSGIRefServer())...
# Listening on http://localhost:8080/
# Hit Ctrl-C to quit.

# %%
from bottle import route, run

@route('/hello')
def hello():
    return "What's up my hello!"

run(host='localhost', port=8080)
# Out:
# Bottle v0.13.4 server starting up (using WSGIRefServer())...
# Listening on http://localhost:8080/
# Hit Ctrl-C to quit.

# %% [markdown]
# 已重启 Python 3.14.5

# %%
from bottle import route, run

@route('/hello')
def hello():
    return "What's up my hello!"

run(host='localhost', port=8080)
# Out:
# Bottle v0.13.4 server starting up (using WSGIRefServer())...
# Listening on http://localhost:8080/
# Hit Ctrl-C to quit.
#
# 127.0.0.1 - - [23/Jul/2026 14:19:10] "GET / HTTP/1.1" 404 726
# 127.0.0.1 - - [23/Jul/2026 14:19:17] "GET /hello HTTP/1.1" 200 19
# 127.0.0.1 - - [23/Jul/2026 14:19:37] "GET /hello HTTP/1.1" 200 19
# 127.0.0.1 - - [23/Jul/2026 14:19:37] "GET /hello HTTP/1.1" 200 19
# 127.0.0.1 - - [23/Jul/2026 14:19:38] "GET /hello HTTP/1.1" 200 19
# 127.0.0.1 - - [23/Jul/2026 14:19:49] "GET / HTTP/1.1" 404 726
# 127.0.0.1 - - [23/Jul/2026 14:19:53] "GET /hello HTTP/1.1" 200 19
# 127.0.0.1 - - [23/Jul/2026 14:20:09] "GET /hello HTTP/1.1" 200 19
# 127.0.0.1 - - [23/Jul/2026 14:20:18] "GET /hello HTTP/1.1" 200 19
# 127.0.0.1 - - [23/Jul/2026 14:20:19] "GET /hello HTTP/1.1" 200 19
# 127.0.0.1 - - [23/Jul/2026 14:20:19] "GET /hello HTTP/1.1" 200 19
# 127.0.0.1 - - [23/Jul/2026 14:20:20] "GET /hello HTTP/1.1" 200 19
# 127.0.0.1 - - [23/Jul/2026 14:20:37] "GET / HTTP/1.1" 404 726
# 127.0.0.1 - - [23/Jul/2026 14:20:44] "GET /hello HTTP/1.1" 200 19
# 127.0.0.1 - - [23/Jul/2026 14:20:47] "GET /hello HTTP/1.1" 200 19
# 127.0.0.1 - - [23/Jul/2026 14:21:33] "GET / HTTP/1.1" 404 726
# 127.0.0.1 - - [23/Jul/2026 14:21:39] "GET /hello HTTP/1.1" 200 19

# %%
from bottle import route, run

@route('/hello')
def hello():
    return "What's up my hello!"

run(host='localhost', port=8080, debug=True)

# %%
from bottle import route, run

@route('/hello')
def hello():
    return "What's up my hello!"

run(host='localhost', port=8080, debug=True)

# %%
from bottle import route, run

@route('/hello')
def hello():
    return "koujiba"

run(host='localhost', port=8080, debug=True)

# %%
from bottle import route, run

@route('/hello')
def hello():
    return "koujiba"

run(host='localhost', port=8080, debug=True)

# %%
from bottle import route, run

@route('/hello')
def hello():
    return "koujiba"

run(host='localhost', port=8080, debug=True)

# %%
from bottle import route, run

@route('/hello')
def hello():
    return "koujiba"

run(host='localhost', port=8080, debug=True)

# %%
from bottle import route, run

@route('/hello')
def hello():
    return "koujiba"

run(host='localhost', port=8080, debug=True)
